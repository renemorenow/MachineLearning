# %%
#Importar las librerias para los graficos:
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
#Importar numpy python
import numpy as np

# %%
#Importar el sample generator de scikit-learn - make blobs
from sklearn.datasets.samples_generator import make_blobs

# %%
#Graficarlo
X,Y = make_blobs(n_samples=300, centers=4)

plt.scatter(X[:,0], X[:,1], s=50)

# %%
# K-means de scikit-learn
from sklearn.cluster import KMeans

# %%
#K-means
kmeans = KMeans(n_clusters=5)

# %%
#Entrenar algoritmo
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
#Clusters labels
y_means = kmeans.predict(X)

# %%
#Centroid values
centers = kmeans.cluster_centers_
print(centers)
# Out:
# [[ 3.64425021  4.33793724]
#  [ 8.94035077 -8.2708018 ]
#  [-3.09782249 -3.66623963]
#  [-3.44266393  5.5169125 ]
#  [-4.32927078 -2.38403032]]

# %%
#Graficar valores conjuntos
plt.scatter(X[:,0], X[:,1], c=y_means, cmap='viridis')

#Incluidos los centroides
plt.scatter(centers[:,0], centers[:,1], c='red', s=200, alpha=0.5);

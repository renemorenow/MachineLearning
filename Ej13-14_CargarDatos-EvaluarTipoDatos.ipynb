# %%
import numpy as np
import pandas as pd #Permite trabajar con texto
#Libreria para graficos:
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn as sklearn
#from sklearn.preprocessing import preprocessing

# %%
#Permitir que los graficos sean renderizados directamente en nuestro Notebook, para ir haciendo analisis de datos
# %matplotlib inline

# %%
#cargar datos directo a panda desde donde se encuentra el archivo en platzi, usando google colab podemos usar lo siguiente:
#movies1 = pd.read_csv('https://static.platzi.com/media/public/uploads/peliculas_3169fc13-a8ff-4b9a-b125-3a94c1e5f6d4.csv',encoding='utf-8')
#Del PC
movies = pd.read_csv(r'D:\Dev\MachineLearning\peliculas_3169fc13-a8ff-4b9a-b125-3a94c1e5f6d4.csv',encoding='utf-8')

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
#Metodo para ver los primeros elementos:
movies.head()
# Out:
#                                          movie_title  title_year  color  \
# 0                                            Avatar       2009.0  Color
# 1          Pirates of the Caribbean: At World's End       2007.0  Color
# 2                                           Spectre       2015.0  Color
# 3                             The Dark Knight Rises       2012.0  Color
# 4  Star Wars: Episode VII - The Force Awakens    ...         NaN    NaN
#
#    aspect_ratio  duration language country  duration.1  \
# 0          1.78     178.0  English     USA       178.0
# 1          2.35     169.0  English     USA       169.0
# 2          2.35     148.0  English      UK       148.0
# 3          2.35     164.0  English     USA       164.0
# 4           NaN       NaN      NaN     NaN         NaN
#
#                             genres content_rating  \
# 0  Action|Adventure|Fantasy|Sci-Fi          PG-13
# 1         Action|Adventure|Fantasy          PG-13
# ...

# %%
movies.shape
# Out:
# (5043, 19)

# %%
movies.columns
# Out:
# Index(['movie_title', 'title_year', 'color', 'aspect_ratio', 'duration',
#        'language', 'country', 'duration.1', 'genres', 'content_rating',
#        'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'cast_total_facebook_likes', 'budget', 'imdb_score',
#        'gross'],
#       dtype='object')

# %%
#Ver los revistros
movies.index
# Out:
# RangeIndex(start=0, stop=5043, step=1)

# %%
#Acceder a columnas
columna1 = movies['movie_title']
columna1.head()
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
# Acceder a filas:
linea = movies.loc[10,:]
linea
# Out:
# movie_title                                Batman v Superman: Dawn of Justice
# title_year                                                                2016
# color                                                                    Color
# aspect_ratio                                                              2.35
# duration                                                                   183
# language                                                               English
# country                                                                    USA
# duration.1                                                                 183
# genres                                                 Action|Adventure|Sci-Fi
# content_rating                                                           PG-13
# plot_keywords                based on comic book|batman|sequel to a reboot|...
# director_name                                                      Zack Snyder
# ...

# %%
movies.loc[:,"movie_title"].head()
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
#Separar tipos de dato (numericos, texto)
movies.dtypes
# Out:
# movie_title                   object
# title_year                   float64
# color                         object
# aspect_ratio                 float64
# duration                     float64
# language                      object
# country                       object
# duration.1                   float64
# genres                        object
# content_rating                object
# plot_keywords                 object
# director_name                 object
# actor_1_name                  object
# actor_2_name                  object
# actor_3_name                  object
# cast_total_facebook_likes      int64
# budget                       float64
# imdb_score                   float64
# gross                        float64
# dtype: object

# %%
type(movies.dtypes)
# Out:
# pandas.core.series.Series

# %%
#Verificar cuales son flotantes
movies.dtypes == float
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
movies.dtypes == int
# Out:
# movie_title                  False
# title_year                   False
# color                        False
# aspect_ratio                 False
# duration                     False
# language                     False
# country                      False
# duration.1                   False
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                       False
# imdb_score                   False
# gross                        False
# dtype: bool

# %%
(movies.dtypes == int) | (movies.dtypes == float)
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
movies.dtypes == object
# Out:
# movie_title                   True
# title_year                   False
# color                         True
# aspect_ratio                 False
# duration                     False
# language                      True
# country                       True
# duration.1                   False
# genres                        True
# content_rating                True
# plot_keywords                 True
# director_name                 True
# actor_1_name                  True
# actor_2_name                  True
# actor_3_name                  True
# cast_total_facebook_likes    False
# budget                       False
# imdb_score                   False
# gross                        False
# dtype: bool

# %%
num = (movies.dtypes == int) | (movies.dtypes == float)
num
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
num.index
# Out:
# Index(['movie_title', 'title_year', 'color', 'aspect_ratio', 'duration',
#        'language', 'country', 'duration.1', 'genres', 'content_rating',
#        'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'cast_total_facebook_likes', 'budget', 'imdb_score',
#        'gross'],
#       dtype='object')

# %%
for el in num.index:
    print(el)
# Out:
# movie_title
# title_year
# color
# aspect_ratio
# duration
# language
# country
# duration.1
# genres
# content_rating
# plot_keywords
# director_name
# actor_1_name
# actor_2_name
# actor_3_name
# cast_total_facebook_likes
# budget
# imdb_score
# gross

# %%
#Dejar solo las columnas numericas
num_cols = [c for c in num.index if num[c]]
num_cols
# Out:
# ['title_year',
#  'aspect_ratio',
#  'duration',
#  'duration.1',
#  'budget',
#  'imdb_score',
#  'gross']

# %%
#Obtener las otras columnas:
obj = (movies.dtypes == object)
obj_cols = [c for c in obj.index if obj[c]]

# %%
obj_cols
# Out:
# ['movie_title',
#  'color',
#  'language',
#  'country',
#  'genres',
#  'content_rating',
#  'plot_keywords',
#  'director_name',
#  'actor_1_name',
#  'actor_2_name',
#  'actor_3_name']

# %%
#Columnas, Cantidad no-null, Tipo dato
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 19 columns):
# movie_title                  5043 non-null object
# title_year                   4935 non-null float64
# color                        5024 non-null object
# aspect_ratio                 4714 non-null float64
# duration                     5028 non-null float64
# language                     5031 non-null object
# country                      5038 non-null object
# duration.1                   5028 non-null float64
# genres                       5043 non-null object
# content_rating               4740 non-null object
# plot_keywords                4890 non-null object
# director_name                4939 non-null object
# actor_1_name                 5036 non-null object
# actor_2_name                 5030 non-null object
# actor_3_name                 5020 non-null object
# cast_total_facebook_likes    5043 non-null int64
# ...

# %%
movies.dtypes
# Out:
# movie_title                   object
# title_year                   float64
# color                         object
# aspect_ratio                 float64
# duration                     float64
# language                      object
# country                       object
# duration.1                   float64
# genres                        object
# content_rating                object
# plot_keywords                 object
# director_name                 object
# actor_1_name                  object
# actor_2_name                  object
# actor_3_name                  object
# cast_total_facebook_likes      int64
# budget                       float64
# imdb_score                   float64
# gross                        float64
# dtype: object

# %%
#15. Inspección cuantitativa y de salud de los datos
num_cols
movies_num_cols = movies[num_cols]
movies_num_cols.head()
# Out:
#    title_year  aspect_ratio  duration  duration.1       budget  imdb_score  \
# 0      2009.0          1.78     178.0       178.0  237000000.0         7.9
# 1      2007.0          2.35     169.0       169.0  300000000.0         7.1
# 2      2015.0          2.35     148.0       148.0  245000000.0         6.8
# 3      2012.0          2.35     164.0       164.0  250000000.0         8.5
# 4         NaN           NaN       NaN         NaN          NaN         7.1
#
#          gross
# 0  760505847.0
# 1  309404152.0
# 2  200074175.0
# 3  448130642.0
# 4          NaN

# %%
movies_num_cols.describe()
# Out:
#         title_year  aspect_ratio     duration   duration.1        budget  \
# count  4935.000000   4714.000000  5028.000000  5028.000000  4.551000e+03
# mean   2002.470517      2.220403   107.201074   107.201074  3.975262e+07
# std      12.474599      1.385113    25.197441    25.197441  2.061149e+08
# min    1916.000000      1.180000     7.000000     7.000000  2.180000e+02
# 25%    1999.000000      1.850000    93.000000    93.000000  6.000000e+06
# 50%    2005.000000      2.350000   103.000000   103.000000  2.000000e+07
# 75%    2011.000000      2.350000   118.000000   118.000000  4.500000e+07
# max    2016.000000     16.000000   511.000000   511.000000  1.221550e+10
#
#         imdb_score         gross
# count  5043.000000  4.159000e+03
# mean      6.442138  4.846841e+07
# std       1.125116  6.845299e+07
# min       1.600000  1.620000e+02
# 25%       5.800000  5.340988e+06
# 50%       6.600000  2.551750e+07
# 75%       7.200000  6.230944e+07
# max       9.500000  7.605058e+08

# %%
obj_cols
movies_obj_cols = movies[obj_cols]
movies_obj_cols
# Out:
#                                             movie_title             color  \
# 0                                               Avatar              Color
# 1             Pirates of the Caribbean: At World's End              Color
# 2                                              Spectre              Color
# 3                                The Dark Knight Rises              Color
# 4     Star Wars: Episode VII - The Force Awakens    ...               NaN
# 5                                          John Carter              Color
# 6                                         Spider-Man 3              Color
# 7                                              Tangled              Color
# 8                              Avengers: Age of Ultron              Color
# 9               Harry Potter and the Half-Blood Prince              Color
# 10                  Batman v Superman: Dawn of Justice              Color
# 11                                    Superman Returns              Color
# ...

# %%
movies_obj_cols.describe()
# Out:
#                       movie_title  color language country genres  \
# count                        5043   5024     5031    5038   5043
# unique                       4917      2       47      65    914
# top     The Fast and the Furious   Color  English     USA  Drama
# freq                            3   4815     4704    3807    236
#
#        content_rating   plot_keywords     director_name    actor_1_name  \
# count            4740            4890              4939            5036
# unique             18            4760              2398            2097
# top                 R  based on novel  Steven Spielberg  Robert De Niro
# freq             2118               4                26              49
#
#           actor_2_name  actor_3_name
# count             5030          5020
# unique            3032          3521
# top     Morgan Freeman  Steve Coogan
# freq                20             8

# %%
movies_num_cols['duration']
# Out:
# 0       178.0
# 1       169.0
# 2       148.0
# 3       164.0
# 4         NaN
# 5       132.0
# 6       156.0
# 7       100.0
# 8       141.0
# 9       153.0
# 10      183.0
# 11      169.0
# 12      106.0
# 13      151.0
# 14      150.0
# 15      143.0
# 16      150.0
# 17      173.0
# 18      136.0
# 19      106.0
# 20      164.0
# 21      153.0
# 22      156.0
# 23      186.0
# 24      113.0
# 25      201.0
# 26      194.0
# 27      147.0
# 28      131.0
# 29      124.0
#         ...
# 5013     79.0
# 5014     80.0
# 5015    100.0
# 5016     90.0
# 5017     90.0
# 5018    120.0
# 5019     91.0
# 5020    143.0
# 5021     85.0
# 5022     60.0
# 5023     88.0
# 5024     78.0
# 5025    108.0
# 5026    110.0
# 5027     90.0
# 5028     83.0
# 5029    111.0
# 5030     84.0
# 5031     82.0
# 5032     98.0
# 5033     77.0
# 5034     80.0
# 5035     81.0
# 5036     84.0
# 5037     95.0
# 5038     87.0
# 5039     43.0
# 5040     76.0
# 5041    100.0
# 5042     90.0
# ...

# %%
movies_num_cols['duration'].hist()

# %%
movies_num_cols['imdb_score'].hist()

# %%
movies_num_cols['budget'].hist()

# %%
(movies_num_cols['budget'] > 1e9).value_counts()
# Out:
# False    5037
# True        6
# Name: budget, dtype: int64

# %%
#Peliculas con presupuesto mayores a 1 Billon
mask = (movies_num_cols['budget'] > 1e9)
movies[mask]
# Out:
#              movie_title  title_year  color  aspect_ratio  duration  \
# 2323  Princess Mononoke       1997.0  Color          1.85     134.0
# 2334           Steamboy       2004.0  Color          1.85     103.0
# 2988           The Host       2006.0  Color          1.85     110.0
# 3005           Fateless       2005.0  Color          2.35     134.0
# 3423              Akira       1988.0  Color          1.85     124.0
# 3859     Lady Vengeance       2005.0  Color          2.35     112.0
#
#        language      country  duration.1  \
# 2323   Japanese        Japan       134.0
# 2334   Japanese        Japan       103.0
# 2988     Korean  South Korea       110.0
# 3005  Hungarian      Hungary       134.0
# 3423   Japanese        Japan       124.0
# 3859     Korean  South Korea       112.0
#
#                                                  genres content_rating  \
# 2323                        Adventure|Animation|Fantasy          PG-13
# ...

# %%
#16. Limpiar los datos:
pd.read_csv(r'D:\Dev\MachineLearning\thenumbers.csv',sep=';',encoding='utf-8')
# Out:
#      Release Date                                       movie_title  \
# 0      12/18/2009                                            Avatar
# 1       5/20/2011       Pirates of the Caribbean: On Stranger Tides
# 2        5/1/2015                           Avengers: Age of Ultron
# 3      12/18/2015              Star Wars Ep. VII: The Force Awakens
# 4       5/24/2007          Pirates of the Caribbean: At World’s End
# 5       11/6/2015                                           Spectre
# 6       7/20/2012                             The Dark Knight Rises
# 7        7/2/2013                                   The Lone Ranger
# 8        3/9/2012                                       John Carter
# 9      11/24/2010                                           Tangled
# 10       5/4/2007                                      Spider-Man 3
# 11       5/6/2016                        Captain America: Civil War
# 12      3/25/2016                Batman v Superman: Dawn of Justice
# ...

# %%
#Guardar datos en variable:
financials = pd.read_csv(r'D:\Dev\MachineLearning\thenumbers.csv',sep=';',encoding='utf-8')
financials = financials[['movie_title','production_budget','worldwide_gross']]

# %%
financials.head()
# Out:
#                                    movie_title  production_budget  \
# 0                                       Avatar        425000000.0
# 1  Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                      Avengers: Age of Ultron        330600000.0
# 3         Star Wars Ep. VII: The Force Awakens        306000000.0
# 4     Pirates of the Caribbean: At World’s End        300000000.0
#
#    worldwide_gross
# 0       2783918982
# 1       1045663875
# 2       1408218722
# 3       2058662225
# 4        963420425

# %%
gross_opening = pd.read_csv(r'D:\Dev\MachineLearning\thenumbers.csv',sep=';',encoding='utf-8')

# %%
financials.shape
# Out:
# (5435, 3)

# %%
movies.shape
# Out:
# (5043, 19)

# %%
movies_num_cols
# Out:
#       title_year  aspect_ratio  duration  duration.1       budget  imdb_score  \
# 0         2009.0          1.78     178.0       178.0  237000000.0         7.9
# 1         2007.0          2.35     169.0       169.0  300000000.0         7.1
# 2         2015.0          2.35     148.0       148.0  245000000.0         6.8
# 3         2012.0          2.35     164.0       164.0  250000000.0         8.5
# 4            NaN           NaN       NaN         NaN          NaN         7.1
# 5         2012.0          2.35     132.0       132.0  263700000.0         6.6
# 6         2007.0          2.35     156.0       156.0  258000000.0         6.2
# 7         2010.0          1.85     100.0       100.0  260000000.0         7.8
# 8         2015.0          2.35     141.0       141.0  250000000.0         7.5
# 9         2009.0          2.35     153.0       153.0  250000000.0         7.5
# 10        2016.0          2.35     183.0       183.0  250000000.0         6.9
# ...

# %%
#Peliculas * movie_title
movies['movie_title'].head()
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
movies_num_cols.head()
# Out:
#    title_year  aspect_ratio  duration  duration.1       budget  imdb_score  \
# 0      2009.0          1.78     178.0       178.0  237000000.0         7.9
# 1      2007.0          2.35     169.0       169.0  300000000.0         7.1
# 2      2015.0          2.35     148.0       148.0  245000000.0         6.8
# 3      2012.0          2.35     164.0       164.0  250000000.0         8.5
# 4         NaN           NaN       NaN         NaN          NaN         7.1
#
#          gross
# 0  760505847.0
# 1  309404152.0
# 2  200074175.0
# 3  448130642.0
# 4          NaN

# %%
#Concatenar columna movie_title
movies_num_cols = pd.concat([movies_num_cols, movies['movie_title']],axis=1)

# %%
#gross_opening = gross_opening.drop('Unnamed: 0',axis=1)

# %%
movies_v2 = pd.merge(financials,movies_num_cols,on='movie_title',how='left')

# %%
movies_v2 = pd.merge(financials,movies_num_cols,on='movie_title',how='left')

# %%
movies_v2.shape
# Out:
# (5435, 10)

# %%
#17. Manejo de datos faltantes

# %%
#Los False es porque hay datos faltantes
movies_v2.notnull()
# Out:
#       movie_title  production_budget  worldwide_gross  title_year  \
# 0            True               True             True       False
# 1            True               True             True       False
# 2            True               True             True       False
# 3            True               True             True       False
# 4            True               True             True       False
# 5            True               True             True       False
# 6            True               True             True       False
# 7            True               True             True       False
# 8            True               True             True       False
# 9            True               True             True       False
# 10           True               True             True       False
# 11           True               True             True       False
# 12           True               True             True       False
# ...

# %%
help(pd.Series.value_counts)
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : boolean, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : boolean, default True
#         Sort by values.
#     ascending : boolean, default False
#         Sort in ascending order.
#     bins : integer, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : boolean, default True
#         Don't include counts of NaN.
#
#     Returns
#     -------
# ...

# %%
movies_v2.notnull().apply(pd.Series.value_counts)
# Out:
#        movie_title  production_budget  worldwide_gross  title_year  \
# False          NaN                435              NaN      5435.0
# True        5435.0               5000           5435.0         NaN
#
#        aspect_ratio  duration  duration.1  budget  imdb_score   gross
# False        5435.0    5435.0      5435.0  5435.0      5435.0  5435.0
# True            NaN       NaN         NaN     NaN         NaN     NaN

# %%
#Rellenar datos faltantes:
(movies_v2 != 0).apply(pd.Series.value_counts)
# Out:
#        movie_title  production_budget  worldwide_gross  title_year  \
# False          NaN                NaN              357         NaN
# True        5435.0             5435.0             5078      5435.0
#
#        aspect_ratio  duration  duration.1  budget  imdb_score   gross
# False           NaN       NaN         NaN     NaN         NaN     NaN
# True         5435.0    5435.0      5435.0  5435.0      5435.0  5435.0

# %%
available = ((movies_v2 != 0) & (movies_v2.notnull()))

# %%
available.head()
# Out:
#    movie_title  production_budget  worldwide_gross  title_year  aspect_ratio  \
# 0         True               True             True       False         False
# 1         True               True             True       False         False
# 2         True               True             True       False         False
# 3         True               True             True       False         False
# 4         True               True             True       False         False
#
#    duration  duration.1  budget  imdb_score  gross
# 0     False       False   False       False  False
# 1     False       False   False       False  False
# 2     False       False   False       False  False
# 3     False       False   False       False  False
# 4     False       False   False       False  False

# %%
#.all(revisa todas las lineas)
available.all(axis=1).value_counts()
# Out:
# False    5435
# dtype: int64

# %%
#No podemos entrenar nuestro algoritmo con datos cuya variable objetivo no esta definida o sea nula (valor falso). Eliminemos esas líneas.
mask = available['worldwide_gross']
mask
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 5405    False
# 5406     True
# 5407    False
# 5408    False
# 5409    False
# 5410    False
# 5411    False
# 5412     True
# 5413     True
# 5414    False
# 5415     True
# 5416     True
# 5417    False
# 5418     True
# 5419     True
# 5420     True
# 5421     True
# 5422     True
# 5423     True
# 5424    False
# 5425     True
# 5426     True
# 5427     True
# 5428     True
# 5429     True
# 5430     True
# 5431     True
# 5432    False
# 5433    False
# 5434     True
# ...

# %%
movies_v2 = movies_v2[mask]

# %%
((movies_v2 != 0) & (movies_v2.notnull())).worldwide_gross.value_counts()
# Out:
# True    5078
# Name: worldwide_gross, dtype: int64

# %%
#help(sklearn.preprocessing)
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
values = imputer.fit_transform(movies_v2)
X = pd.DataFrame(values)
X.columns = movies_v2.columns
X.index = movies_v2.index
X.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-265-0aad1901c33a> in <module>
# ----> 1 values = imputer.fit_transform(movies_v2)
#       2 X = pd.DataFrame(values)
#       3 X.columns = movies_v2.columns
#       4 X.index = movies_v2.index
#       5 X.head()
#
# ~\AppData\Local\ESRI\conda\envs\my_arcgispro-py3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~\AppData\Local\ESRI\conda\envs\my_arcgispro-py3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     266         self : SimpleImputer
#     267         """
# ...
